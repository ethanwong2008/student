# %% [raw]
# ---
# title: Final Retrospective
# layout: post
# permalink: /csp-retrospective
# ---

# %% [markdown]
# 1. compare beginigng and end
# 2. 3 key things from all sprints
# 3. how was natm?
# 4. What do you want to do on the next project?
# 5. what do you want to learn?
# 6. analytics review
# 7. MCQ

# %% [markdown]
# ## How I Changed This Year
#
# In the begining of the year I was not communicating with my tablemates and was working on whatever was assigned to me and just got everything done by myself. Over the course of our first tri I slowley started to communicate with my group as I started to feel more comfortable. Although I can now communicate with my group much better I am still unable to communicate wth the class as a whole.
#
#
# ## 3 Key Things
#
# Throught the tri I worked on many projects that all helped build my CS skills. I created a bell api that keeps track of out schools bell which is manualy put in but It can tell you when the next bell is and what class you are currently in. Next I made a HW project that would help other start learning basic API usage. And finally I worked on the main homescreen for the classes digital famine home screen.
#
# ## How N@TM Went
#
# N@TM went pretty good with everyone who tried the game enjoying our sub moduales. Throught N@TM we did enounter bugs that are difficult to find withought having lots of play tester play our section of the project. I loved all the great feedback we got as it can help me create a smoother experince for the next project we make.
#
# ## What Will The Next project Look Like?
#
# In the next large project I take part in I would like to focus more on creating a smooth user expeince with little to no bugs allowing for anyone to easily test / use the project created. I would also focu on creating better communication for the groups taking place in the project for example due to slack being blocked on school wifi and due to many people not having it, I would create a discord server to better communicate as its very commenly used.
#
# ## What Do I Want to learn
#
# I`ll make this simple, API, ad Back end :)
#
# ## Analytics
#
# Throught this tri I have These Analytics
#
# 48 Commits
# 20 Issues
# 4 PR`s
# +101335 / -595 Lines changed
#
# Keep in mind these are not very accurate as some commits are not being counted
#
#
# In my opinion I was very active and participated in the projects I helped in.
#
#
#
# # MCQ
#
# My idea for taking this mc test is to better undertand topics that we have not learned and topics that we will learn soon. The mcq had some questions that made me exited for the future of csp and somequestion that felt not needed.
#
#
#
# # Correction For MC
# Score 39 / 66 (not the best)
#
# The main group of questions that were missed were more vocabulary based as they contained words that I had no idea what they meant. I failed to notice some edge cases in some of the questions which should have been seen. The last questions the required multiple answers were almost all missed. I understand what I got wrong and how to fix them as they are either vocab or simple mistakes
