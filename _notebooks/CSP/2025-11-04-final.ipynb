# %% [raw]
# ---
# layout: post
# toc: True
# title: Final Retrospective
# description: This is my CSP final for trimester 1. This is my review and reflection on all the work that I have done this trimester.
# permalink: /csp/final/review/
# author: Ethan Wong
# ---
